# %% [markdown]
# # Downloading DA data

# %%
# -------------------------------------------------------------------
# concat_zip_csvs.py   –  Run from the folder that holds the ZIP files
# -------------------------------------------------------------------
import zipfile
from pathlib import Path
import pandas as pd

# -------------------------------------------------------------------
# 1.  Where are the ZIPs?
# -------------------------------------------------------------------
ZIP_DIR   = Path.cwd()  / "../data"         # change if zips live elsewhere
print(f"Loading ZIPs from {ZIP_DIR}")

frames = []                     # accumulate individual DataFrames
# -------------------------------------------------------------------
# 2.  Loop over every *.zip in that folder
# -------------------------------------------------------------------
for zpath in sorted(ZIP_DIR.glob("*.zip")):   # sort for deterministic order
    print(f"Loading {zpath.name}...")
    with zipfile.ZipFile(zpath) as zf:
        # assume exactly ONE csv inside
        csv_name = [n for n in zf.namelist() if n.lower().endswith(".csv")]
        if len(csv_name) != 1:
            raise ValueError(f"{zpath} should contain exactly one CSV")
        csv_name = csv_name[0]

        # read the CSV directly into pandas
        with zf.open(csv_name) as f:
            df = pd.read_csv(f)              # pass file-like object
            df["source_zip"] = zpath.name    # optional provenance column
            frames.append(df)

        print(f"✔ loaded {csv_name} from {zpath.name}")
# Out:
# Loading ZIPs from c:\Users\benja\OneDrive\Bureau\UchicagoMSFM\Financing_Grid_final_project\code\..\data
# Loading 2022_Oct-Dec_DA_LMPs.zip...
# ✔ loaded 2022_Oct-Dec_DA_LMPs.csv from 2022_Oct-Dec_DA_LMPs.zip
# Loading 2023_Apr-Jun_DA_LMPs.zip...
# ✔ loaded 2023_Apr-Jun_DA_LMPs.csv from 2023_Apr-Jun_DA_LMPs.zip
# Loading 2023_Jan-Mar_DA_LMPs.zip...
# ✔ loaded DA.csv from 2023_Jan-Mar_DA_LMPs.zip
# Loading 2023_Jul-Sep_DA_LMPs.zip...
# C:\Users\benja\AppData\Local\Temp\ipykernel_29712\302330150.py:29: DtypeWarning: Columns (14,15,16,17,18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f)              # pass file-like object
# ✔ loaded DA.csv from 2023_Jul-Sep_DA_LMPs.zip
# Loading 2023_Oct-Dec_DA_LMPs.zip...
# ✔ loaded DA.csv from 2023_Oct-Dec_DA_LMPs.zip
# Loading 2024-Jul-Sep_DA_LMPs.zip...
# ✔ loaded DA.csv from 2024-Jul-Sep_DA_LMPs.zip
# Loading 2024-Oct-Dec_DA_LMPs.zip...
# ✔ loaded DA.csv from 2024-Oct-Dec_DA_LMPs.zip
# Loading 2024_Apr-Jun_DA_LMPs.zip...
# C:\Users\benja\AppData\Local\Temp\ipykernel_29712\302330150.py:29: DtypeWarning: Columns (18,19,20,21,22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f)              # pass file-like object
# ✔ loaded DA.csv from 2024_Apr-Jun_DA_LMPs.zip
# Loading 2024_Jan-Mar_DA_LMPs.zip...
# C:\Users\benja\AppData\Local\Temp\ipykernel_29712\302330150.py:29: DtypeWarning: Columns (4,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f)              # pass file-like object
# ✔ loaded DA.csv from 2024_Jan-Mar_DA_LMPs.zip
# Loading 2025_Jan-Mar_DA_LMP.zip...
# C:\Users\benja\AppData\Local\Temp\ipykernel_29712\302330150.py:29: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f)              # pass file-like object
# ✔ loaded DA.csv from 2025_Jan-Mar_DA_LMP.zip

# %%
all_df = pd.concat(frames, ignore_index=True)

# %%
all_df
# Out:
#         MARKET_DAY         NODE       TYPE VALUE    HE1    HE2    HE3    HE4  \
# 0        10/1/2022         AECI  Interface   LMP  25.34  24.61  25.60  24.66
# 1        10/1/2022         AECI  Interface   MCC  -9.42  -8.52  -6.95  -8.35
# 2        10/1/2022         AECI  Interface   MLC  -2.32  -2.84  -2.79  -2.83
# 3        10/1/2022    AECI.ALTW   Loadzone   LMP   28.0  26.00  26.00  25.95
# 4        10/1/2022    AECI.ALTW   Loadzone   MCC  -6.99  -9.12  -8.51  -9.04
# ...            ...          ...        ...   ...    ...    ...    ...    ...
# 6612391  3/31/2025  WR.THAYERLD   Loadzone   MCC  -1.04  -0.92  -0.47  -0.13
# 6612392  3/31/2025  WR.THAYERLD   Loadzone   MLC   0.24   0.24   0.24   0.25
# 6612393  3/31/2025          YAD  Interface   LMP  25.02  24.26  24.05  25.38
# 6612394  3/31/2025          YAD  Interface   MCC    0.5   0.32   0.61   0.93
# 6612395  3/31/2025          YAD  Interface   MLC    0.8   0.78   0.76   0.80
#
#            HE5    HE6  ...   HE16   HE17   HE18   HE19   HE20   HE21   HE22  \
# 0        27.42  32.57  ...  45.05  47.91  52.38  52.04  41.39  34.38  32.99
# 1        -8.25  -5.83  ...  -3.33  -3.32   -2.5  -2.45   -3.7  -4.15  -0.54
# 2        -2.90  -3.14  ...  -2.89  -2.99  -3.18  -3.91  -3.76  -3.30  -2.64
# 3        30.55  35.35  ...  42.69  46.07  51.21  52.11  41.99  33.55  24.64
# 4        -7.23  -5.33  ...  -6.13  -6.09  -4.66  -4.59   -5.0  -6.99 -10.60
# ...        ...    ...  ...    ...    ...    ...    ...    ...    ...    ...
# 6612391   0.20   0.38  ...  -7.24  -8.45  -9.25  -5.74  -4.71  -1.76  -1.07
# 6612392  -0.17   0.13  ...   0.24   0.25   0.31  -0.59  -1.35  -0.97   0.34
# 6612393  28.07  35.41  ...  32.35  33.67  39.92   59.8   72.4  53.90  44.67
# 6612394   1.77   1.78  ...  -3.63   -4.2  -4.46  -2.06  -0.63   0.34  -0.31
# 6612395   0.09   0.80  ...   0.92   0.96   1.14   0.04  -1.62  -1.18   1.19
#
#           HE23   HE24                source_zip
# 0        26.14  25.97  2022_Oct-Dec_DA_LMPs.zip
# 1        -3.69  -2.91  2022_Oct-Dec_DA_LMPs.zip
# 2        -2.63  -1.94  2022_Oct-Dec_DA_LMPs.zip
# 3        24.95  21.97  2022_Oct-Dec_DA_LMPs.zip
# 4        -6.16  -7.10  2022_Oct-Dec_DA_LMPs.zip
# ...        ...    ...                       ...
# 6612391  -0.25  -1.17   2025_Jan-Mar_DA_LMP.zip
# 6612392   0.01  -0.25   2025_Jan-Mar_DA_LMP.zip
# 6612393  40.72  34.82   2025_Jan-Mar_DA_LMP.zip
# 6612394   0.14   2.06   2025_Jan-Mar_DA_LMP.zip
# 6612395   0.36  -0.06   2025_Jan-Mar_DA_LMP.zip
#
# [6612396 rows x 29 columns]

# %%
set(all_df['NODE'])  # check column names
# Out:
# {'DPC.FLAMBEAU',
#  'DECO.JUDD12',
#  'CONS.PAL_HEPM',
#  'CONS.WPMC',
#  'CONS.GYRD1WPSC',
#  'MEC.MACKSBURG',
#  'ALTW.DASOLAR2',
#  'AMIL.KIMMEL',
#  'MIUP.MAGAZESH',
#  'SME.BENN.ARR',
#  'DECO.FERMI2',
#  'EES.OXBOW',
#  'NSP.INVRHL5',
#  'BREC.AZ',
#  'EAI.PLUM2_MEUC',
#  'AMIL.REI2CTGC',
#  'AMMO.OSAGEEGEN',
#  'CONS.CC.MICHP',
#  'CONS.MPPA.CHSE',
#  'MIUP.GARSPV2',
#  'DECO.HNKP113',
#  'EES.MTCPS_ST1',
#  'MEC.PLYMOUTH1',
#  'WR.MEUCLADD',
#  'AMIL.RLGY01',
#  'DPC.MCNEILUS2',
#  'DECO.ET.COMMC',
#  'ALTW.ODINWF',
#  'CLEC.HUNTER5',
#  'MIUP.CHALKHILL',
#  'WEC.KAC_ISPP',
#  'MEC.CHASCS_W',
#  'ALTW.CERROG1',
#  'NSP.SARTELL',
#  'AMMO.PENOCTG2',
#  'IPL.WVPA',
#  'WPS.WESTON14',
#  'OTP.BRDRS1.WND',
#  'AMIL.DR.DELTA',
#  'BREC.SKILLMAN',
#  'AMIL.SWECCTG1',
#  'WPS.WESTON11',
#  'AMIL.BSEINDIP1',
#  'WEC.ERG2',
#  'ALTW.PRARC4',
#  'NSP.BLUEL3',
#  'AMMO.WVPA_3.AZ',
#  'EAI.CWAYLD',
#  'MEC.CORALV1',
#  'NSP.NSPG.SHC3L',
#  'OTP.OTPW_12.AZ',
#  'MDU.GLENULST_6',
#  'EES.DEMCO',
#  'EES.RCTHOMAS',
#  'OKGE',
#  'EES.AMITESO',
#  'MGE.BLTPLTG6',
#  'EES.STLNG3.ARR',
#  'SIGE.IMPA',
#  'MEC.BEAVERCR',
#  'EDE.PLUM',
#  'MGE.DRR.DG10',
#  'NSP.BELW_1.AZ',
#  'AMIL.BALDSSAUX',
#  'MHEB',
#  'AMIL.DR.MES',
#  'EES.SLEMCO',
#  'ALTW.DR.FERGLD',
#  'AMIL.INDRAIL',
#  'MEC.POCHNT_1',
#  'CONS.SCWND1',
#  'GRE.GRE',
#  'AMMO.WVPA.CZML',
#  'OPPD',
#  'CONS.HODENPYL',
#  'NIPS.CC.WHITN',
#  'CLEC.ORIN',
#  'AMIL.STWF',
#  'NSP.AEPE3',
#  'CONS.MCV.MCV',
#  'AMIL.XOEN',
#  'NSP.LYONC.MVP',
#  'NSP.NOBLES.WND',
#  'EAI.WTBLF5.ARR',
#  'AMIL.PSGC1.KMP',
#  'GRE.ELMCR2_IBR',
#  'CIN.WVPA.BNLIL',
#  'WEC.PB2AUX',
#  'CIN.MARKLND.3',
#  'EES.WATRFD4_CT',
#  'AMIL.SWE_IL',
#  'ALTW.RIPPEY1',
#  'CONS.RENAIGEN2',
#  'EAI.JONSCWL',
#  'AMIL.SOY_2.AZ',
#  'AMIL.DR.AREP',
#  'AMIL.COG_ACOGG',
#  'AMIL.DUCKC.ARR',
#  'WEC.JOU_WMONT',
#  'EES.WLWGN1.ARR',
#  'EAI.CC.UPS1',
#  'ALTW.FCLDFCL1',
#  'NSP.OAKLKE_IBR',
#  'MGE.DRR.DG08',
#  'IPL.16PETEE4',
#  'DECO.STCLP12',
#  'GRE.LKFLGR3',
#  'AMIL.L69_AHOPK',
#  'OTP.OTPW_14.AZ',
#  'AMIL.DR.PRIN',
#  'AEP.PSGC2.AMP',
#  'CONS.CRESCENT',
#  'CIN.PSI.IMPA',
#  'MGE.HERMSDORF',
#  'AMMO.SIOUX1',
#  'WPS.WESTON15',
#  'WPS.COLUMBIA2',
#  'ALTW.BRLGTN1',
#  'CONS.FICTYEC',
#  'CONS.GENESEPS',
#  'AMMO.LABADIE2',
#  'CONS.PAL_WPSC',
#  'NSP.MRES_5.AZ',
#  'EAI.BLAKELY1',
#  'EES.LFSF',
#  'AMIL.SFE_IL',
#  'DECO.NESL1',
#  'EAI.UPS2_CT1',
#  'CWLD.SIKESTON',
#  'HE.07LCPGEN1',
#  'EES.CONWAY.ARR',
#  'NSP.GRE.BFRDG',
#  'AMMO.KIRK_1.AZ',
#  'EAI.AECCOSWCT5',
#  'MEC.MEAN_1.AZ',
#  'ALTW.BRLGTN4',
#  'INDN',
#  'CONS.LUDINGTN1',
#  'ALTW.LKFLD.IPL',
#  'WEC.GLACRHLS',
#  'WEC.DR.WEPM',
#  'MDU.BEPC',
#  'AMIL.BALDWI51',
#  'AMMO.KIRK',
#  'EMBA.HINDS1_ST',
#  'EES.MTCPSCT1',
#  'EES.ACADA2.ARR',
#  'WPS.TWOCRK1S',
#  'SIGE.HE',
#  'AMMO.MARC_1.AZ',
#  'ALTW.EMERY32',
#  'CONS.CCG_6.AZ',
#  'AEP.PSGC1.AMP',
#  'NSP.MANKATOCT1',
#  'NSP.INVRHL1',
#  'CONS.CA3_WPSC',
#  'AMIL.WRSF',
#  'AMIL.TRA_ATRAE',
#  'LAFA.HARGIS2',
#  'NSP.MORAINE2',
#  'NSP.HAMPTN.MVP',
#  'AMIL.VEM',
#  'YAD',
#  'MP.DR.JFK',
#  'SIGE.CANL2.AMP',
#  'DECO.MISEC',
#  'ALTW.TOI_2.3',
#  'AMMO.MEXCTG1',
#  'CIN.ESR.NABB',
#  'NSP.CC.HIBRDG2',
#  'CIN.SUCRKGT1',
#  'AMMO.PRSPWF',
#  'MEC.WSEC4',
#  'MP.MRES',
#  'GLH.MEPI4',
#  'WR.MEUCFRED2',
#  'ALTE.CRAWFISH',
#  'ALTW.PRESCOTT',
#  'MPS.CROSSROAD2',
#  'NSP.MANKATST32',
#  'AMIL.ELD120',
#  'AMMO.PNKYCTG7',
#  'AMIL.WDRV.ARR',
#  'NSP.BE2',
#  'MEC.CENTURY_1',
#  'AMMO.FGRDCTG1',
#  'AMIL.DR.ANNA',
#  'CLEC.CPWR_6.AZ',
#  'DECO.DEAN12',
#  'MIUP.KUESTER14',
#  'ALTW.JOUNEAL3',
#  'LAGN.LOGC.ARR',
#  'ALTE.NEENAHG1',
#  'CIN.PSI_2.AZ',
#  'EES.LKCHAR_CT2',
#  'NSP.HCPD.GRVCT',
#  'ALTE.SFONDDLG2',
#  'AMIL.PSGC2.PPI',
#  'EES.ACAD2_CT1',
#  'ALTW.SLAK_CT1',
#  'AMIL.SWEC.ARR',
#  'CIN.CT.VERMN.2',
#  'MEC.AZ',
#  'EAI.DEGRAY2',
#  'AMMO.AUDRN11',
#  'ALTW.MGS_CT2',
#  'AMIL.CCG_1.AZ',
#  'NIPS.WHITNGT1',
#  'AMIL.PUBPOWIL',
#  'AMIL.DR.SEL',
#  'EES.UCB',
#  'FE',
#  'EES.DOWCHEMSUP',
#  'AMIL.XLON',
#  'AMMO.RUSHIS2',
#  'MEC.SHENDO_1',
#  'NSP.BUFFR_TR1',
#  'AMIL.CALRIDGE',
#  'CONS.GENESEE',
#  'NSP.DANIELSN1',
#  'NSP.STJM_1.AZ',
#  'EKPC',
#  'EMBA.AEPE17',
#  'OTP.MRES.NTWD',
#  'EES.JAXSNS.ARR',
#  'CONS.BSE.CEC',
#  'AMMO.MERAMEC3',
#  'EAI.CARPNTR_2',
#  'GRE.GRE.CXS',
#  'NSP.CODA.BYLL',
#  'CONS.CEREALSO',
#  'AMIL.NORRISDC',
#  'EAI.CWL_C',
#  'EES.CARV_A',
#  'CONS.CNE',
#  'OTP.HOOTL3',
#  'WPS.GLU',
#  'EES.NELSON6',
#  'CONS.LUDINGTN6',
#  'EES.JWL_ST1',
#  'CONS.ZEELAND1A',
#  'NSP.VALYVIEW1',
#  'AMIL.ELD150',
#  'AMMO.WVPA.CZPG',
#  'NIPS.USS',
#  'EES.NOPLD',
#  'NSP.FRENCH3',
#  'CLEC.VIGN1.ARR',
#  'CIN.LOGANOAKR',
#  'CIN.SUCRKST1',
#  'NSP.BSTAR1.WND',
#  'ALTE.TOWNEST12',
#  'BREC.SEBREE',
#  'NIPS.MUNSTR.LN',
#  'NSP.IBR.YANKE',
#  'MGE.DRR.DG02',
#  'CONS.HARDY',
#  'EAI.AECCOSWCT7',
#  'NSP.MENOMOA',
#  'IPL.16STOUTR1',
#  'AMMO.PNKYCTG6',
#  'DECO.NEP131',
#  'ALTW.TOI_MGEO',
#  'CIN.HENRYCO.3',
#  'AMIL.DR.SLGN',
#  'MEC.MEAN_3.AZ',
#  'NIPS.PRAXAIR',
#  'NSP.RAPID.ARR',
#  'NSP.ANSON2',
#  'EAI.AECCLD',
#  'MIUP.CLVHDRTN1',
#  'AECI.APM_1.AZ',
#  'NSP.CISCO1',
#  'UPPC.ESC',
#  'AMIL.CPW_GS',
#  'AMIL.FORDCO1',
#  'OTP.HLSOLAR',
#  'CONS.KARN1',
#  'SMP.BLOOMIN_QS',
#  'CONS.COVRT1_GT',
#  'AMIL.SIPM_1.AZ',
#  'EES.NINEM1.ARR',
#  'GRE.LKFLGR4',
#  'SME.MORRO.ARR',
#  'DECO.WPSA',
#  'DECO.DEAN122',
#  'EES.UMBRIELSOL',
#  'EAI.BIGCYP20',
#  'MIUP.KUESTER12',
#  'EAI.PLUM_1C',
#  'EES.OUACH_2',
#  'EES.STLNG1.ARR',
#  'CWLP.CWLP',
#  'ALTW.DRUN.ESR1',
#  'CONS.COVERT2G',
#  'CONS.KARN4',
#  'NSP.ST_PETER',
#  'MEC.ROLLHILL_1',
#  'WEC.PS_ESR1',
#  'EAI.WH_BLUFF2',
#  'CWLD.CWLD',
#  'AMIL.LINCLAND1',
#  'LAFA.LABBE1',
#  'ILGEN10.AGG',
#  'OTP.ASTORIA',
#  'DECO.MONROE4',
#  'HE.CIN',
#  'ALTW.INDEPWIND',
#  'OTP.MPC.YNG2',
#  'ALTE.NEENAHG2',
#  'AMIL.AVTN',
#  'NSP.ODELL.WND',
#  'EES.EXXON',
#  'LAFA.LAFA',
#  'NSP.MANKATOCT2',
#  'ALTE.JUN31.ARR',
#  'ALTW.SLAK_R1',
#  'ALTE.WPPI_1.AZ',
#  'ALTW.TEA_1.AZ',
#  'CONS.KAL_RGEN_',
#  'NSP.CORNEL',
#  'EES.AIRLIQ_GEI',
#  'CIN.HEPM_2.AZ',
#  'WEC.KAUCBL.ARR',
#  'CIN.MARKLND.1',
#  'AMIL.GME1',
#  'CIN.CT.VERMN.1',
#  'AMIL.PSGC2.AMP',
#  'OTP.NSPG_1.AZ',
#  'MGE.BLT_ESR1',
#  'AMIL.WPSE',
#  'AMMO.CC.OSAGE',
#  'AMIL.NEWTON21',
#  'DECO.BRP121',
#  'ALTW.HCPD.STHP',
#  'CIN.CT.VERMN.3',
#  'DECO.NEP132',
#  'EES.ETEC_1.AZ',
#  'OTP.MDU.COYOTE',
#  'AMIL.VIN_AVINT',
#  'AMIL.PSG1.MEUC',
#  'ALTW.BEPM.CBLD',
#  'NSP.WHEATO6',
#  'AMMO.MORUCTG1',
#  'MINN.HUB',
#  'AMIL.AMILSES',
#  'ALTW.ADAMSADAM',
#  'CONS.FESC',
#  'NSP.SHERC2.SLR',
#  'DECO.EXGNMW2',
#  'WEC.PARIS01S3',
#  'NIPS.AZ',
#  'ALTW.ENGLFARMS',
#  'OTP.MRES_8.AZ',
#  'AMIL.PS2.NIMP',
#  'CWLD.CEC2CTG4',
#  'CWLP.AZ',
#  'MIUP.SPARTAN',
#  'DMGEN2.AGG',
#  'CONS.LIVINGEN3',
#  'GRE.NSP.GREC',
#  'AMMO.OSAGE8',
#  'CONS.CCG_3.AZ',
#  'CLEC.VIGN2.ARR',
#  'CONS.CC.ZEELA2',
#  'NSP.WISSOT_TR4',
#  'GRE.TEA_1.AZ',
#  'CONS.ZEELAND2A',
#  'WEC.VALLYGA1',
#  'LAGN.BYCT1',
#  'NSP.SHAKOBIO1',
#  'SIGE.10ABBGN2',
#  'NSP.DR.COMPUTE',
#  'EES.SAN_JC2_CT',
#  'UPPC.ONTONAGON',
#  'EES.BASTP1.ARR',
#  'MEC.SER.COMP',
#  'UPPC.WPPI',
#  'WR.MEUCFRED1',
#  'IPL.HEPM_1.AZ',
#  'ALTE.SHEB2',
#  'EAI.WMPSOL',
#  'SME.MOS_5',
#  'MEC.EL_FARM_3',
#  'MEC.ARBHILL_S',
#  'CONS.CAMPBELL1',
#  'ALTW.JOULGSIPL',
#  'ALTW.LIMEC1',
#  'MEC.PHEC_2',
#  'CIN.NIPS.GBSNS',
#  'AMIL.HSNVL.ARR',
#  'AMMO.KEOKUK1',
#  'EES.L_CREEK2',
#  'AMMO.MARC_NEM',
#  'AMIL.CSTNCTG1',
#  'MIUP.WPSE',
#  'EMBA.G_ANDRUS1',
#  'GRE.MAPLEMAPL',
#  'CWLD.CEC2CTG1',
#  'CONS.HRTLND',
#  'AMIL.REN1',
#  'AMIL.CCG_5.AZ',
#  'AMMO.TS2',
#  'CONS.PARKV.ARR',
#  'EES.NSIDE2.ARR',
#  'NSP.ADAMSWD1',
#  'AMIL.DR.THYSS',
#  'AMMO.GOOSEGEN3',
#  'MGE.CARDNL.MVP',
#  'ALTE.WAUTOMA',
#  'CLEC.CLEC',
#  'NSP.HIBRDG9_1',
#  'IPL.16EVST9',
#  'IPL.16GEOR11G',
#  'MEC.MEAN_7.AZ',
#  'ALTW.SLAK_R3',
#  'OTP.AZ',
#  'AMIL.EIPS3',
#  'CONS.KENCNTY1',
#  'OTP.RUGBY1UPLS',
#  'MIUP.CLOV',
#  'MIUP.MARQ',
#  'CLEC.CPWR_3.AZ',
#  'SME.GPTAYLRS',
#  'DECO.LUD4',
#  'AMIL.BOOMTOWN',
#  'ALTW.PRARC3',
#  'LAGN.BC1T_3',
#  'CIN.GIBSON.1',
#  'MEC.ATLN',
#  'CLEC.CPS71',
#  'AMMO.KEOKUK10',
#  'AMIL.SIPC.BGRV',
#  'MEC.ADAMS',
#  'NSP.BUFFR_TR2',
#  'NSP.WHEATO2',
#  'AMIL.DR.AREP1',
#  'NIPS.CAVALRYBS',
#  'WEC.OCONTFL',
#  'EAI.PLUMPT',
#  'NSP.KING1',
#  'AMIL.GDTOWER3',
#  'LEPA.HOUMA',
#  'ALTE.NLSD1.ARR',
#  'DECO.GWDP111',
#  'DECO.NEP112',
#  'MEC.PALOALTO1',
#  'NSP.MANKATST31',
#  'EES.SRMPA',
#  'CONS.ALPENTHBA',
#  'AMIL.IOW_AFRYT',
#  'MIUP.GARSPV1',
#  'IPL.16STOUCC6',
#  'AMIL.CEEA2',
#  'EES.OUACH_3',
#  'DECO.BLR1.MPPA',
#  'MEC.AMES',
#  'CIN.SIGE',
#  'DUK',
#  'GRE.NSP',
#  'EAI.AECCOSWCT3',
#  'DECO.BELRV.MVP',
#  'NSP.ALDRIHERC',
#  'AMMO.KIRK2.ARR',
#  'CONS.ALPENA',
#  'ALTW.CRYSTAL3',
#  'DECO.LUD2',
#  'CLEC.AXLA_1.AZ',
#  'EMBA.WILDWDSO',
#  'ALTW.MONTA.ARR',
#  'EES.SABINE3',
#  'WR.MOWR',
#  'EMBA.SUNFLOWER',
#  'NSP.MINRVR1',
#  'UPPC.AUTRAIN',
#  'EAI.AECCMGVMST',
#  'EES.BASTAP.ARR',
#  'MEC.CHICKASAW',
#  'LAGN.CTW2',
#  'AMIL.BIGRIVER',
#  'ALTW.MOWERCO',
#  'NSP.NCP.AZ',
#  'ALTE.KILBOUNIL',
#  'CWLD.FULT',
#  'DECO.DLRYP12',
#  'AMMO.PNKYCTG5',
#  'EMBA.PRVS',
#  'DECO.DIGS3',
#  'DECO.PINNEBOG',
#  'ALTW.SLAK_CT2',
#  'NSP.CMMPA.SE',
#  'OTP.MPC.OLVIII',
#  'CONS.LIVINGEN1',
#  'AMIL.AMS_ASTOR',
#  'NIPS.BAILY.ARR',
#  'MEC.CC.GDM1',
#  'EAI.REMMEL123',
#  'EAI.INDEPEND1',
#  'EMBA.CHCTWCT1',
#  'EES.CC.LKCHAR',
#  'EES.WATRFD2',
#  'AMIL.NEC1_1.AZ',
#  'EES.WATRFD1',
#  'ALTW.LANS3.ARR',
#  'UPPC.INTEGRATD',
#  'ALTW.RCCS.ARR',
#  'DECO.DFWE2',
#  'MIUP.MANSTQN1',
#  'MEC.MEAN_10.AZ',
#  'MGE.DRR.DG04',
#  'MPS.CROSSROAD1',
#  'NSP.GRANTY.ARR',
#  'DPC.NWEC.AZ',
#  'HMPL.HMPL_1.AZ',
#  'CIN.NIPS.JRDCK',
#  'AMIL.W_BRCTIPT',
#  'AMMO.MARC_NG',
#  'NIPS.AM',
#  'NIPS.CARGILL',
#  'DECO.BWEC.12',
#  'CONS.CROTON',
#  'GRE.MMPA',
#  'WEC.ROOT_PIKE',
#  'EAI.NPTSOL',
#  'IPL.16STOU7O7',
#  'AMIL.SELC',
#  'MEC.ARBORHL1',
#  'MIUP.PEAVYFALL',
#  'EES.DERSLD',
#  'MDU.TATANKALD',
#  'LEPA.LEPA',
#  'SIPC.MARI69',
#  'CONS.JAXON_2',
#  'GLH.EEI7B2',
#  'MP.HVDCE',
#  'AMMO.OSAGE7',
#  'EAI.DR.BIGRST',
#  'ALTE.1ROCKGEN',
#  'CLEC.CPWR_7.AZ',
#  'AMIL.DR.SES',
#  'MEC.CORALV3',
#  'WPS.MENOMPK',
#  'WPS.OCONTO.MP',
#  'WEC.PLSNT1.MVP',
#  'CSWS.HOPE',
#  'NIPS.OAKDAPOAK',
#  'MP.HPUGEN356',
#  'MP.HPULOAD',
#  'GRE.NSP.CXS',
#  'EAI.H_SPR1_CT1',
#  'AMMO.RCCKCTG4',
#  'NSP.PVALEY.WND',
#  'WEC.GERMANOT5',
#  'DECO.STCLA.ARR',
#  'NSP.BLUE_LK7',
#  'CONS.CC.COVRT1',
#  'SIPC.AZ',
#  'SIGE.10ABBGN1',
#  'WPS.MPU',
#  'AMIL.TILTU3',
#  'MEC.CORALV2',
#  'MDU.FOXTL.WND',
#  'NSP.WPPI',
#  'AMIL.DR.ADM',
#  'EES.TAFTCOGEN',
#  'MIUP.DETRDBN1',
#  'EES.STERL7',
#  'OTP.GRE.ASHTII',
#  'NSP.STCLOUD1',
#  'DECO.LUD3',
#  'EES.NSIDE1.ARR',
#  'NSP.CH_DIR_TR4',
#  'OTP.GRE.DSA',
#  'CONS.WPSC_2.AZ',
#  'DECO.BRP122',
#  'CONS.SPRTN',
#  'EMBA.HVGSOL',
#  'EES.FRONT_TX1',
#  'GRE.MORA__2_5',
#  'CONS.GYRD3WPSC',
#  'NSP.SHERCO3.CO',
#  'NSP.CMMPA.DEL',
#  'OTP.OTPW_11.AZ',
#  'DMGEN1.AGG',
#  'MP.WPPI_BOS4',
#  'EES.WLTGR1.ARR',
#  'EES.VIGNES.ARR',
#  'MEC.KNOXIN_1',
#  'BREC.SMTH2.AMP',
#  'ALTW.FAIR1.ARR',
#  'BREC.PADUCAH1',
#  'DECO.STCLP11',
#  'ALTW.TOI_MGEP',
#  'AMIL.DR.WIEL',
#  'AMMO.KEOKUK12',
#  'WPS.WEM33',
#  'CE.ZIONEC.MVP',
#  'NYISO',
#  'CIN.EDWCT1',
#  'EAI.SHRDN2.ARR',
#  'NIPS.IMPA',
#  'AMMO.KAHO_1.AZ',
#  'MP.MPM_1.AZ',
#  'OTP.LANGDN2',
#  'CWLD.CEC2CTG2',
#  'WEC.S',
#  'LAGT.1803',
#  'CONS.DR.CETR',
#  'CIN.SUGRCK.MVP',
#  'AMIL.HOOPESTON',
#  'WPS.BDGHLW1S',
#  'MEC.PHEC_3',
#  'MPS.CROSSROAD3',
#  'IPL.PEC01',
#  'AMIL.ALSEYCTG5',
#  'DECO.FRMP112',
#  'AMMO.WVPA.CZHI',
#  'AMMO.KEOKUK3',
#  'EES.BASTR2.ARR',
#  'AMIL.ALSEYCTG6',
#  'WEC.PORTWA1ST0',
#  'AMIL.THNK',
#  'EAI.CC.HT_SPR1',
#  'AMIL.DR.PLLA',
#  'ALTW.HANCO_PE',
#  'AMIL.MRDSA.ARR',
#  'DECO.DR.POET',
#  'WEC.CC.PORTW2',
#  'CIN.GALGHR.ARR',
#  'AMMO.KEOKUK15',
#  'EES.MORIL1.ARR',
#  'OTP.GRE',
#  'DECO.DEAN34',
#  'AMIL.PSGC2.KMP',
#  'MIUP.WPPI',
#  'AMMO.HIPRAIRIE',
#  'SMP.MMPA.AU',
#  'OTP.DR3.WND',
#  'ALTW.UPLS_2.AZ',
#  'EES.NELSON2',
#  'NSP.BLKDO5',
#  'DECO.GWDP112',
#  'EAI.DR.OIS',
#  'DECO.CROS',
#  'AMMO.VENCTG3',
#  'ALTW.NSP',
#  'ALTE.EDG3.ARR',
#  'NSP.GDMEADOW',
#  'AMIL.EIPS4',
#  'WEC.PARISSLR1',
#  'SIGE.WARR4SIGE',
#  'GRE.ELKRI4',
#  'OTP.NSPX.ADA',
#  'MGE.OBRIEN_W',
#  'AMIL.EDWARDS2',
#  'CONS.PINERVR1',
#  'GRE.BEPM.CWT',
#  'DECO.DR.TRGT',
#  'IPL.IPL',
#  'SIPC.MARIOGEN5',
#  'MEC.RHILLS58',
#  'WPS.WESTON17',
#  'AMIL.DR.IVEX',
#  'OTP.MPC.ASH2',
#  'MGE.HKP_ESR1',
#  'CONS.LBWL.CSEL',
#  'CONS.LUDINGTN2',
#  'MEC.MEAN_2.AZ',
#  'AMMO.SIKESTON',
#  'NIPS.INCROSWF',
#  'NSP.WPPI_1.AZ',
#  'OTP.GREM_2.AZ',
#  'AMIL.CASS',
#  'CONS.DR.WPSC',
#  'AMIL.DR.JPPA',
#  'AMIL.WPSE.OLIN',
#  'AMIL.CIPS.BOC',
#  'EES.BURAS.ARR',
#  'EES.ELMP_1.AZ',
#  'EAI.AECCWCSOL',
#  'NIPS.CARPNTRWF',
#  'ALTE.SFONDDLG3',
#  'EES.NOPS_6',
#  'SIGE.WAR5SIGE',
#  'DECO.HNKP111',
#  'TVA.BRMNH1.ARR',
#  'CWLD.DR.CWLD',
#  'CSWS.AEPM_1.AZ',
#  'MDU.DIAMNDWILW',
#  'SIGE.WAR4SIGE',
#  'OTP.COYOT1',
#  'NSP.REDWIN2',
#  'MIUP.DFTR13N1',
#  'DECO.NEP114',
#  'CLEC.CPS6ST',
#  'CLEC.ACA13',
#  'SME.DTEDGE',
#  'EAI.UPS3_CT2',
#  'AMMO.LINN_1.AZ',
#  'ALTW.CRLK2WPL',
#  'MEC.WALNUT_W1',
#  'CWLP.DALLMA84',
#  'ALTW.ENDV',
#  'BREC.WILSON1',
#  'SIGE.AZ',
#  'DECO.DEAN112',
#  'EAI.ANO2',
#  'AMIL.TILTU2',
#  'ALTW.PIOPRAIR1',
#  'EES.DR.ELLPT1',
#  'NSP.MMPA.FEP',
#  'NSP.JIMFL',
#  'CONS.COVRT3_GT',
#  'CONS.MIPOWER2',
#  'ALTW.TOI',
#  'CLEC.CPWR_5.AZ',
#  'SME.PLUMPOINT',
#  'DLCO',
#  'DECO.OSHEA.BES',
#  'CIN.CAYCT.4',
#  'MEC.RLGY01',
#  'NSP.BLKDO6',
#  'OTP.MDU.BSTON1',
#  'SMP.PVWIND',
#  'NIPS.MICHCP12',
#  'AMIL.ALSEYCTG2',
#  'MEC.EL_FARM_1',
#  'NSP.FRENCH1',
#  'EES.LKCHAR_ST',
#  'WPS.LAKEFRN96',
#  'EES.L_CREEK1',
#  'CONS.COVRT1_ST',
#  'AMMO.CALF_1.AZ',
#  'CIN.WHEATCTG3',
#  'MEC.HCPD.ABRN',
#  'NSP.CHEMOLSPO',
#  'SPC',
#  'MEC.GDMEC_1',
#  'MEC.CFU7',
#  'HE.MEROM_CH1',
#  'SME.MOS_CTG_1',
#  'CONS.SELC',
#  'ALTW.FXLK3.ARR',
#  'AMMO.WFSP',
#  'AMMO.UE.AZ',
#  'SME.SLVRCRK_1',
#  'MDU.MDU',
#  'AMIL.TILTU4',
#  'DPL',
#  'AMMO.AUDRN55',
#  'CLEC.RPS2.LEPA',
#  'CSWS.SWERETAIL',
#  'NSP.CMMPA.GF',
#  'MEC.RIVSID.ARR',
#  'CONS.MSCP_1.AZ',
#  'MGE.JOUCOLUM2',
#  'NSP.NWELOAD',
#  'CE.PSG2.IMEA',
#  'NSP.WHEATO3',
#  'EAI.AECCOSWCT4',
#  'AMIL.RISING.H',
#  'WEC.OKCGC7',
#  'DECO.DEERFLD',
#  'NSP.SPGSPG1',
#  'CIN.GIBSON.4',
#  'EMBA.CHCTWCT3',
#  'AMIL.EIPS5',
#  'MPS',
#  'GRE.MOWER2',
#  'AMMO.PERR',
#  'AMIL.ACP9',
#  'CONS.LIVINGEN2',
#  'EES.WATRFD3',
#  'LAFA.AZ',
#  'NSP.RIVRSD72',
#  'SWPP',
#  'ALTE.WRIVS_CT2',
#  'NSP.CMMPA.GLEN',
#  'BREC.CENTURY',
#  'GRE.LKFLGR2',
#  'ALTW.EMERY_1',
#  'MEC.ROLLHILL_3',
#  'NIPS.ERC_TEST',
#  'CIN.WRHILND',
#  'AMIL.DR.UNIV',
#  'ALTW.FAIR_SIG',
#  'WEC.PTBHGB1',
#  'OTP.TATANKA',
#  'IPL.AZ',
#  'AMIL.AEM.SYLND',
#  'AMIL.MULLIGAN',
#  'AMIL.REI2CTGE',
#  'NSP.ALTW',
#  'AMIL.PSG2.LGEP',
#  'CONS.NESL',
#  'NSP.COYOTE',
#  'ALTW.UPLANDPR',
#  'CLEC.ERATH',
#  'MEC.STORMLK_1',
#  'AMIL.DEB_ALTON',
#  'DECO.BRP13',
#  'LAGN.BC1T_4',
#  'ALTW.KOSSUTH2',
#  'EES.BXTRW5.ARR',
#  'NSP.RIVRSD71',
#  'EES.MAGPOWG',
#  'NSP.INVRHL2',
#  'GRE.HUC',
#  'MEC.GDMEC_1_3',
#  'AECI.APM_2.AZ',
#  'CONS.RENAIGEN4',
#  'CLEC.CPWR_4.AZ',
#  'DPC.EKM2',
#  'MEC.MEAN_4.AZ',
#  'CONS.EXGNBB1B',
#  'NSP.BE1',
#  'MEC.BEPM_WS4',
#  'ALTE.WOODCTY',
#  'ALTW.MECB',
#  'AMIL.GBCCTG2',
#  'ALTW.BART1WPPI',
#  'OTP.HETLA',
#  'LEPA.HOUMA_G16',
#  'EAI.PBENRGY_ST',
#  'ALTW.SOUTH.FRK',
#  'CIN.CRANESOLAR',
#  'EES.ACADA1.ARR',
#  'EAI.CWL_A',
#  'CIN.CONRSV.ARR',
#  'GRE.LKFLGR1',
#  'WAUE.HANCCBPC',
#  'EES.NEWTON',
#  'DPC.EDNF',
#  'DPC.AEPE9',
#  'NSP.CWN2',
#  'WPS.WESTON13',
#  'WEC.OKCGC6',
#  'DECO.HVSTW',
#  'ALTW.SACCOWIND',
#  'EES.NOPS_7',
#  'ILGEN7.AGG',
#  'BREC.SMTH1.AMP',
#  'DECO.GWDP12',
#  'MP.DLPLOAD',
#  'AMIL.SUGARCRK',
#  'MIUP.WHITERAPD',
#  'AMIL.WVPA',
#  'AMIL.TILTU1',
#  'MEC.MECB',
#  'OTP.MPWR',
#  'CE.CRETE.NU',
#  'LAGN.BCI_1',
#  'EAI.EAILD.RLA',
#  'EES.AXLPLQ',
#  'IPL.16SYST.AGG',
#  'OTP.MMPA',
#  'NSP.NSPG_2.AZ',
#  'WPS.CRANECREK',
#  'DECO.OLIVRP11',
#  'CE.PSG1.N_PSG',
#  'LOUISIANA.HUB',
#  'LAGN.CTW1',
#  'AMIL.AEM.MUNI',
#  'HE.MEROM_AUX',
#  'EAI.CC.BLAKLY',
#  'NSP.PRISL1',
#  'IPL.16PETEE2',
#  'ALTW.BARTON2',
#  'OTP.HILS_1.AZ',
#  'WEC.CC.PORTW1',
#  'EAI.BLAKELY2',
#  'CONS.CC.COVERT',
#  'WEC.PS_ESR1_LD',
#  'CLEC.MPS3',
#  'ALTE.CASSVILLE',
#  'EES.MTCPSST1',
#  'EES.STLNG5.ARR',
#  'AMIL.SIPC',
#  'DECO.FESC',
#  'MDU.MPC',
#  'WEC.GERMANOT2',
#  'AMIL.BSEINDC1',
#  'NIPS.WVPA_1.AZ',
#  'AMMO.UA.AZ',
#  'MGE.LRRGTOT',
#  'ALTW.NCENT.ARR',
#  'NSP.CMMPA.KASS',
#  'EMBA.G_GULF_N',
#  'NSP.UPLS_1.AZ',
#  'WEC.RBC1',
#  'AMIL.CIPS.ROB',
#  'EAI.CROSSETT',
#  'NSP.ROCKRIDG1',
#  'CIN.GIBSON.5',
#  'AMMO.DR.AMMO',
#  'CSWS.ETEC_LD',
#  'DECO.GRNWD.MVP',
#  'MEC.LVED_1.AZ',
#  'AMIL.NEWT_1.AZ',
#  'MEC.CLIPR1',
#  'DECO.STCLAIR7',
#  'WPS.CC.FOX2',
#  'CIN.GRNTON.MVP',
#  'EES.CC.MCPS1',
#  'EES.LIBERTY',
#  'WEC.VALLYGA2',
#  'NSP.HIBRDG.7',
#  'MGE.MOREY',
#  'NSP.MARSHSOLAR',
#  'OTP.NSP',
#  'ALTW.ALTW',
#  'AMMO.KEOKUK7',
#  'AMIL.BFESLD',
#  'CLEC.CPS6',
#  'MGE.OBRIEN_S',
#  'NSP.BLUE_LK8',
#  'AMIL.EIPS',
#  'CIN.ESR.ATTBRY',
#  'MDU.HESKET_4',
#  'AMMO.OSAGE2',
#  'DECO.SANDU.MVP',
#  'NIPS.NIPS',
#  'ALTW.HANCOC1',
#  'NSP.HCPD.LKCR',
#  'EES.CNWAY2.ARR',
#  'DPC.WINNEBAGO',
#  'CONS.HEARTLAND',
#  'AMIL.RSPWIND',
#  'CONS.ELIG',
#  'DECO.LUD1',
#  'AMIL.AMER',
#  'CONS.ZEELAND2C',
#  'CSWS.AEPM_3.AZ',
#  'MEC.GENESEO',
#  'HE.WORTH2',
#  'EES.BGTEL1.ARR',
#  'GRE.REC.CC2_AC',
#  'ALTW.FRBRN.WND',
#  'AMIL.EIPS2',
#  'DECO.DIGG3',
#  'AMIL.STAR',
#  'NSP.HCPD.SXFLS',
#  'WPS.UMERC',
#  'MDU.WISHEK1',
#  'WEC.PARIS01S1',
#  'MEC.VICTRM_1',
#  'CIN.PSI.LMU',
#  'DECO.INDRAMI',
#  'EES.BRAZLD',
#  'GRE.ELMCRK',
#  'NSP.GARWIN1',
#  'AMIL.DR.NEVI',
#  'EES.DOWCHEMPK',
#  'CONS.POLRS.SOL',
#  'LAGN.CTW4',
#  'AMIL.DR.SIUE2',
#  'AMIL.VRD',
#  'EES.NINEM6_CT2',
#  'DECO.CC.DIG2',
#  'EES.SRMPA_1.AZ',
#  'NIPS.BCWF.SIG',
#  'BREC.SMTH3.AMP',
#  'BREC.GREEN2',
#  'CIN.CT.VERMN.7',
#  'GLH.MEPI5',
#  'WPS.MEWD_M1',
#  'AMIL.WLBRWEST',
#  'UPPC.WPMC',
#  'AMIL.HEN_AMT_P',
#  'CONS.WVPA_1.AZ',
#  'GRE.WILM',
#  'CLEC.DPS.ARR',
#  'EAI.AECCBAILEY',
#  'OTP.OTP',
#  'EES.TOL_BEND2',
#  'EAI.OMLP_1.AZ',
#  'EMBA.HINDS1CT2',
#  'WEC.EITM_LZ02',
#  'MDU.ELLNDL.MVP',
#  'AMIL.WISE.IWUS',
#  'AMIL.PLST',
#  'EES.SRMPA_IPLD',
#  'AMIL.PSG1.IMPA',
#  'AMIL.PSG1.LGEP',
#  'ALTW.EMERY_2',
#  'DECO.DRRGERDAU',
#  'AMIL.AMBT',
#  'NIPS.LAKES',
#  'EAI.UPS1_CT2',
#  'EAI.AECCMGVCT1',
#  'CIN.TIPMONT',
#  'CLEC.CC.ACAPB1',
#  'EAI.UPS3_CT1',
#  'SME.PALDNG.ARR',
#  'CONS.AESM.CHSE',
#  'AMIL.COSF_SF',
#  'AMIL.BSHPHL3',
#  'EES.BASFVFW',
#  'WPS.LAKEFRN95',
#  'AMIL.MERDS.MVP',
#  ...}

# %%
filtered_df = all_df[all_df["VALUE"] == 'LMP']  
filtered_df = filtered_df[filtered_df['NODE']=='NSP.NWELOAD']

# %%
filtered_df.head()
# Out:
#       MARKET_DAY         NODE      TYPE VALUE    HE1    HE2    HE3    HE4  \
# 5925   10/1/2022  NSP.NWELOAD  Loadzone   LMP  26.23  26.36  27.48  28.07
# 12993  10/2/2022  NSP.NWELOAD  Loadzone   LMP  23.31  22.69  24.87  25.31
# 20061  10/3/2022  NSP.NWELOAD  Loadzone   LMP   7.02   7.78   8.20  11.31
# 27129  10/4/2022  NSP.NWELOAD  Loadzone   LMP  15.53  15.63  16.39  20.82
# 34197  10/5/2022  NSP.NWELOAD  Loadzone   LMP  36.77  35.53  33.56  34.78
#
#          HE5    HE6  ...   HE16   HE17   HE18   HE19   HE20   HE21   HE22  \
# 5925   30.72  33.15  ...  43.93  46.64  51.31  51.11  45.59  38.73  28.53
# 12993  27.82  28.90  ...  43.66  46.46  59.67  62.23  50.72  41.04  30.59
# 20061  19.78  30.68  ...  63.09  63.91  71.42  77.23  63.58  49.66  41.60
# 27129  29.23  44.59  ...  69.04  69.58  73.17  77.02  63.05  54.37  48.23
# 34197  39.71  54.43  ...  65.75  68.03  68.47  69.01  60.72  49.12  43.26
#
#         HE23   HE24                source_zip
# 5925   23.63  23.11  2022_Oct-Dec_DA_LMPs.zip
# 12993  20.68  18.41  2022_Oct-Dec_DA_LMPs.zip
# 20061  29.13  27.66  2022_Oct-Dec_DA_LMPs.zip
# 27129  45.76  44.78  2022_Oct-Dec_DA_LMPs.zip
# 34197  33.95  29.17  2022_Oct-Dec_DA_LMPs.zip
#
# [5 rows x 29 columns]

# %%
OUT_FILE  = ZIP_DIR / "Node_DA.csv"

# %%
# -------------------------------------------------------------------
# 3.  Concatenate and save
# -------------------------------------------------------------------
filtered_df.to_csv(OUT_FILE, index=False)
print(f"\nMerged {len(frames)} files ⇒ {OUT_FILE}")
# Out:
# Merged 10 files ⇒ c:\Users\benja\OneDrive\Bureau\UchicagoMSFM\Financing_Grid_final_project\code\..\data\Node_DA.csv
